# %% [markdown]
# <a href="https://colab.research.google.com/github/Danpollak/Word2Note/blob/master/Classification%20-%20Bidirectional%20Encoder%20With%20Embbedings%20and%20Char%20Embbedings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
import tensorflow
import pickle as pk
from tqdm.notebook import tqdm
import statistics

import tensorflow as tf

from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Embedding, Input, Concatenate
from tensorflow import keras
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Data

# %%
class NoteLang:
    def __init__(self, name):
        self.name = name
        self.word2index = {"unk": 0, "SOS": 1, "EOS": 2, "BREAK": 3}
        self.index2word = {0: "unk", 1: "SOS", 2: "EOS", 3: "BREAK"}
        self.note2index = {"unk": 0, "SOS": 1, "EOS": 2, "BREAK": 3}
        self.index2note = {0: "unk", 1: "SOS", 2: "EOS", 3: "BREAK"}
        self.word_level2index = {"unk": 0, "SOS": 1, "EOS": 2, "BREAK": 3}
        self.index2word_level = {0: "unk", 1: "SOS", 2: "EOS", 3: "BREAK"}
        self.n_words = 4
        self.n_notes = 4
        self.n_word_level = 4

    def addSentence(self, sentence):
        for subword in sentence:
            self.addWord(subword)

    def addWord(self, word):
        subword = word[0]
        note = word[1]
        word_level = word[2]

        # insert subwords
        if subword not in self.word2index:
            self.word2index[subword] = self.n_words
            self.index2word[self.n_words] = subword
            self.n_words += 1

        # insert notes
        if note not in self.note2index:
            self.note2index[note] = self.n_notes
            self.index2note[self.n_notes] = note
            self.n_notes += 1

        # insert word level
        if word_level not in self.word_level2index:
          self.word_level2index[word_level] = self.n_word_level
          self.index2word_level[self.n_word_level] = word_level
          self.n_word_level += 1

    def check_unk(self, subword, vocabulary):
        if subword in vocabulary:
          return vocabulary[subword]
        else:
          return vocabulary["unk"]

    def sentence2index(self,sentence):
        indexed_sentence = [self.check_unk(subword, self.word2index) for subword in sentence]
        return indexed_sentence

    def note_sentence2index(self,sentence):
        indexed_sentence = [self.check_unk(note, self.note2index) for note in sentence]
        return indexed_sentence

    def word_level_sentence2index(self,sentence):
        indexed_sentence = [self.check_unk(word_level, self.word_level2index) for word_level in sentence]
        return indexed_sentence

def order_dataset(dataset, max_line_length, train=True):
    features = []
    labels = []
    words = []
    line_length = 0

    for song in tqdm(dataset):
      line = song[0]
      line_features  = []
      line_label = []
      line_word = []

      line_to_parse = [('SOS', 'SOS', 'SOS')]
      line_to_parse.extend(line)
      line_to_parse.append(('EOS', 'EOS', 'EOS'))

      for subword in line_to_parse:
        line_length+=1

        letter = subword[0]
        line_features.append(letter)

        note = subword[1]
        line_label.append(note)

        word = subword[2]
        line_word.append(word)

      # append whole line to dataset
      features.append(line_features)
      labels.append(line_label)
      words.append(line_word)

      if train:
          # get max line length
          max_line_length = max(max_line_length, line_length)
          line_length=0
          NoteVocab.addSentence(line_to_parse)

    # encode features and labels
    features = [NoteVocab.sentence2index(line) for line in tqdm(features)]
    labels = [NoteVocab.note_sentence2index(line) for line in tqdm(labels)]
    words = [NoteVocab.word_level_sentence2index(line) for line in tqdm(words)]

    # buffer features and labels
    features = [np.pad(line, (0,max_line_length - len(line)), constant_values=2) for line in tqdm(features)]
    labels = [np.pad(line, (0,max_line_length - len(line)), constant_values=2) for line in tqdm(labels)]
    words = [np.pad(line, (0,max_line_length - len(line)), constant_values=2) for line in tqdm(words)]

    # convert to numpy
    features = np.array(features)
    labels = np.array(labels)
    words = np.array(words)

    print("printing shapes for sainty check:")
    print(features.shape)
    print(labels.shape)
    print(words.shape)

    print("printing parsed data for sainty check:")
    print(features[0])
    print(labels[0])
    print(words[0])

    print("Max Line is:")
    print(max_line_length)

    return features, labels, words, max_line_length

def filter_dataset(ds):
    train_set = ds['train']
    test_set = ds['test']
    
    print("Length Before Filtering is:")
    print("Train: " + str(len(train_set)))
    print("Test: " + str(len(test_set)))

    WINDOW_SIZE = 10
    median = statistics.median([len(song[0]) for song in train_set])
    print("Median Length is: " + str(median))

    train_set = [song for song in train_set if len(song[0]) < median and len(song[0]) > (median - WINDOW_SIZE )]
    test_set = [song for song in test_set if len(song[0]) < median and len(song[0]) > (median - WINDOW_SIZE)]

    print("Length After Filtering is:")
    print("Train: " + str(len(train_set)))
    print("Test: " + str(len(test_set)))

    return train_set, test_set

# %% [markdown]
# ## Import Data

# %%
from google.colab import drive
drive.mount('/content/drive')
data_path= '/content/drive/My Drive/Colab Notebooks/DALI/ds_characters_withword_split.pickle'
NoteVocab = NoteLang('word2note')
max_line_length = 0

with open(data_path, 'rb') as pickle_file:
    ds = pk.load(pickle_file)

train_set, test_set = filter_dataset(ds)

features, labels, words, max_line_length = order_dataset(train_set, max_line_length)
features_test, words_test, labels_test, _ = order_dataset(test_set, max_line_length, False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Length Before Filtering is:
# Train: 170725
# Test: 42681
# Median Length is: 23
# Length After Filtering is:
# Train: 56358
# Test: 14192
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# printing shapes for sainty check:
# (56358, 24)
# (56358, 24)
# (56358, 24)
# printing parsed data for sainty check:
# [ 1  4  5  6  7  8  9 10 11  6  7 12  9  5  7 13  9 14 14 12  7  2  2  2]
# [1 4 5 5 3 6 7 7 7 7 3 6 7 7 3 8 9 9 8 9 3 2 2 2]
# [1 4 4 4 3 5 5 5 5 5 3 6 6 6 3 7 7 7 7 7 3 2 2 2]
# Max Line is:
# 24
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# printing shapes for sainty check:
# (14192, 24)
# (14192, 24)
# (14192, 24)
# printing parsed data for sainty check:
# [ 1 13 21 22 10  7  6 21 22  8 14 22 19 16  7 15 25  7 18  9 10 22  7  2]
# [ 1 22 23 23 23  3 60 61 61 61 61 61 61 61  3 33 80  3 85 86 86 86  3  2]
# [  1 117 117 117 117   3   0   0   0   0   0   0   0   0   3  42  42   3
#  566 566 566 566   3   2]
# Max Line is:
# 24

# %% [markdown]
# ## Models

# %% [markdown]
# ## Sentence2Note LSTM

# %%
# Hyperparameters
vocab_size = NoteVocab.n_words
number_of_notes = NoteVocab.n_notes
word_level_vocab = NoteVocab.n_word_level
char_embedding_size = 10
word_embedding_size = 100
LSTM_embedding_size = 100

# %%
# define note architecture
note_encoder_inputs_word = Input(shape=(max_line_length), dtype='float32', name="Note_Encoder_Inputs_Word")
note_decoder_inputs_word = Input(shape=(max_line_length), dtype='float32', name="Note_Decoder_Inputs_Word")

char_embedding_layer = Embedding(input_dim=vocab_size, output_dim=char_embedding_size, input_length=max_line_length, name="character_embedding")
char_encoder_input = char_embedding_layer(note_encoder_inputs_word)
char_decoder_input = char_embedding_layer(note_decoder_inputs_word)

# word level information
word_level_input = Input(shape=(max_line_length), dtype='int32', name="Word_Level_Input")
word_level_embedding_layer = Embedding(input_dim=word_level_vocab, output_dim=word_embedding_size, input_length=max_line_length, name="word_embedding")
word_level_embedding = word_level_embedding_layer(word_level_input)
decoder_input = Concatenate(axis=2)([word_level_embedding, char_decoder_input])

# defining LSTM Encoder
note_encoder_LSTM = LSTM(LSTM_embedding_size, return_state=True, name="Note_Encoder")
note_encoder_LSTM_bidrectional = Bidirectional(note_encoder_LSTM)

# getting LSTM Encoder output
_, note_state_h_fwd, note_state_c_fwd, note_state_h_bkwd, note_state_c_bkwd = note_encoder_LSTM_bidrectional(char_encoder_input)
note_state_h = Concatenate()([note_state_h_fwd, note_state_h_bkwd])
note_state_c = Concatenate()([note_state_c_fwd, note_state_c_bkwd])
note_encoder_states = [note_state_h, note_state_c]
print(note_state_h.shape)
print(note_state_c.shape)

# defining LSTM Decoder
note_decoder_LSTM = LSTM(LSTM_embedding_size*2, return_state=True, return_sequences=True, name="Note_Decoder")
note_decoder_LSTM_bidrectional = Bidirectional(note_decoder_LSTM)
# getting LSTM Decoder output
note_decoder_outputs, _, _ = note_decoder_LSTM(decoder_input, initial_state=note_encoder_states)

# note softmax
note_decoder_dense = Dense(number_of_notes, activation='softmax', name="Note_Softmax")
note_decoder_outputs = note_decoder_dense(note_decoder_outputs)

# model definition for training
model = Model([note_encoder_inputs_word  ,note_decoder_inputs_word, word_level_input], note_decoder_outputs,name="Note_Seq2Seq")

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],weighted_metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]) 
          
model.summary()
keras.utils.plot_model(model, expand_nested=True)
# Out:
# (None, 200)
# (None, 200)
# Model: "Note_Seq2Seq"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Note_Decoder_Inputs_Word (Input [(None, 24)]         0
# __________________________________________________________________________________________________
# Note_Encoder_Inputs_Word (Input [(None, 24)]         0
# __________________________________________________________________________________________________
# Word_Level_Input (InputLayer)   [(None, 24)]         0
# __________________________________________________________________________________________________
# character_embedding (Embedding) (None, 24, 10)       330         Note_Encoder_Inputs_Word[0][0]
#                                                                  Note_Decoder_Inputs_Word[0][0]
# __________________________________________________________________________________________________
# word_embedding (Embedding)      (None, 24, 100)      964100      Word_Level_Input[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) [(None, 200), (None, 88800       character_embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 24, 110)      0           word_embedding[0][0]
#                                                                  character_embedding[1][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 200)          0           bidirectional_6[0][1]
#                                                                  bidirectional_6[0][3]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 200)          0           bidirectional_6[0][2]
#                                                                  bidirectional_6[0][4]
# __________________________________________________________________________________________________
# Note_Decoder (LSTM)             [(None, 24, 200), (N 248800      concatenate_10[0][0]
#                                                                  concatenate_11[0][0]
#                                                                  concatenate_12[0][0]
# __________________________________________________________________________________________________
# Note_Softmax (Dense)            (None, 24, 168)      33768       Note_Decoder[0][0]
# ==================================================================================================
# Total params: 1,335,798
# Trainable params: 1,335,798
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
class_weight_base = {0 : 1, 1 : 0.0001, 2 : 0.0000001, 3: 0.0001}
class_weights = {i : 200 for i in range(4, number_of_notes)}
class_weights.update(class_weight_base)

# %%
checkpoint_filepath = '/content/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

early_stop_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0.0000001, patience=10, verbose=0, mode='min',
    baseline=None, restore_best_weights=False
)

# %%
epochs=50

# %%
# %%time
# input to encoder is the feature sentence
# input to decoder is the hidden and context vector, and feature sentence
train_metadata = model.fit([features, features, words], labels,
          batch_size=32,
          epochs=epochs,
          validation_split=0.3,
          callbacks=[model_checkpoint_callback],
          #class_weight=class_weights,
          )
history = train_metadata.history
# Out:
# Epoch 1/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 2.2507 - sparse_categorical_accuracy: 0.4232 - weighted_sparse_categorical_accuracy: 0.4232 - val_loss: 2.1557 - val_sparse_categorical_accuracy: 0.4280 - val_weighted_sparse_categorical_accuracy: 0.4280
# Epoch 2/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 2.0389 - sparse_categorical_accuracy: 0.4582 - weighted_sparse_categorical_accuracy: 0.4582 - val_loss: 2.2019 - val_sparse_categorical_accuracy: 0.4253 - val_weighted_sparse_categorical_accuracy: 0.4253
# Epoch 3/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.8892 - sparse_categorical_accuracy: 0.4974 - weighted_sparse_categorical_accuracy: 0.4974 - val_loss: 2.2839 - val_sparse_categorical_accuracy: 0.4256 - val_weighted_sparse_categorical_accuracy: 0.4256
# Epoch 4/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.7792 - sparse_categorical_accuracy: 0.5206 - weighted_sparse_categorical_accuracy: 0.5206 - val_loss: 2.3237 - val_sparse_categorical_accuracy: 0.4245 - val_weighted_sparse_categorical_accuracy: 0.4245
# Epoch 5/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.7037 - sparse_categorical_accuracy: 0.5358 - weighted_sparse_categorical_accuracy: 0.5358 - val_loss: 2.3719 - val_sparse_categorical_accuracy: 0.4235 - val_weighted_sparse_categorical_accuracy: 0.4235
# Epoch 6/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.6439 - sparse_categorical_accuracy: 0.5495 - weighted_sparse_categorical_accuracy: 0.5495 - val_loss: 2.4592 - val_sparse_categorical_accuracy: 0.4232 - val_weighted_sparse_categorical_accuracy: 0.4232
# Epoch 7/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.5905 - sparse_categorical_accuracy: 0.5629 - weighted_sparse_categorical_accuracy: 0.5629 - val_loss: 2.4991 - val_sparse_categorical_accuracy: 0.4242 - val_weighted_sparse_categorical_accuracy: 0.4242
# Epoch 8/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.5399 - sparse_categorical_accuracy: 0.5767 - weighted_sparse_categorical_accuracy: 0.5767 - val_loss: 2.5568 - val_sparse_categorical_accuracy: 0.4250 - val_weighted_sparse_categorical_accuracy: 0.4250
# Epoch 9/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.4923 - sparse_categorical_accuracy: 0.5899 - weighted_sparse_categorical_accuracy: 0.5899 - val_loss: 2.6118 - val_sparse_categorical_accuracy: 0.4239 - val_weighted_sparse_categorical_accuracy: 0.4239
# Epoch 10/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.4457 - sparse_categorical_accuracy: 0.6027 - weighted_sparse_categorical_accuracy: 0.6027 - val_loss: 2.6743 - val_sparse_categorical_accuracy: 0.4231 - val_weighted_sparse_categorical_accuracy: 0.4231
# Epoch 11/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.4010 - sparse_categorical_accuracy: 0.6145 - weighted_sparse_categorical_accuracy: 0.6145 - val_loss: 2.7754 - val_sparse_categorical_accuracy: 0.4228 - val_weighted_sparse_categorical_accuracy: 0.4228
# Epoch 12/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.3598 - sparse_categorical_accuracy: 0.6258 - weighted_sparse_categorical_accuracy: 0.6258 - val_loss: 2.8001 - val_sparse_categorical_accuracy: 0.4237 - val_weighted_sparse_categorical_accuracy: 0.4237
# Epoch 13/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.3192 - sparse_categorical_accuracy: 0.6367 - weighted_sparse_categorical_accuracy: 0.6367 - val_loss: 2.8631 - val_sparse_categorical_accuracy: 0.4237 - val_weighted_sparse_categorical_accuracy: 0.4237
# Epoch 14/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.2812 - sparse_categorical_accuracy: 0.6469 - weighted_sparse_categorical_accuracy: 0.6469 - val_loss: 2.9063 - val_sparse_categorical_accuracy: 0.4235 - val_weighted_sparse_categorical_accuracy: 0.4235
# Epoch 15/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.2476 - sparse_categorical_accuracy: 0.6556 - weighted_sparse_categorical_accuracy: 0.6556 - val_loss: 2.9785 - val_sparse_categorical_accuracy: 0.4226 - val_weighted_sparse_categorical_accuracy: 0.4226
# Epoch 16/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.2134 - sparse_categorical_accuracy: 0.6646 - weighted_sparse_categorical_accuracy: 0.6646 - val_loss: 3.0435 - val_sparse_categorical_accuracy: 0.4220 - val_weighted_sparse_categorical_accuracy: 0.4220
# Epoch 17/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.1845 - sparse_categorical_accuracy: 0.6721 - weighted_sparse_categorical_accuracy: 0.6721 - val_loss: 3.0842 - val_sparse_categorical_accuracy: 0.4225 - val_weighted_sparse_categorical_accuracy: 0.4225
# Epoch 18/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.1547 - sparse_categorical_accuracy: 0.6800 - weighted_sparse_categorical_accuracy: 0.6800 - val_loss: 3.1447 - val_sparse_categorical_accuracy: 0.4217 - val_weighted_sparse_categorical_accuracy: 0.4217
# Epoch 19/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.1286 - sparse_categorical_accuracy: 0.6867 - weighted_sparse_categorical_accuracy: 0.6867 - val_loss: 3.2201 - val_sparse_categorical_accuracy: 0.4229 - val_weighted_sparse_categorical_accuracy: 0.4229
# Epoch 20/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.1040 - sparse_categorical_accuracy: 0.6934 - weighted_sparse_categorical_accuracy: 0.6934 - val_loss: 3.2614 - val_sparse_categorical_accuracy: 0.4230 - val_weighted_sparse_categorical_accuracy: 0.4230
# Epoch 21/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0801 - sparse_categorical_accuracy: 0.6997 - weighted_sparse_categorical_accuracy: 0.6997 - val_loss: 3.3201 - val_sparse_categorical_accuracy: 0.4232 - val_weighted_sparse_categorical_accuracy: 0.4232
# Epoch 22/50
# 1233/1233 [==============================] - 23s 18ms/step - loss: 1.0596 - sparse_categorical_accuracy: 0.7045 - weighted_sparse_categorical_accuracy: 0.7045 - val_loss: 3.3601 - val_sparse_categorical_accuracy: 0.4225 - val_weighted_sparse_categorical_accuracy: 0.4225
# Epoch 23/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.0391 - sparse_categorical_accuracy: 0.7098 - weighted_sparse_categorical_accuracy: 0.7098 - val_loss: 3.4237 - val_sparse_categorical_accuracy: 0.4222 - val_weighted_sparse_categorical_accuracy: 0.4222
# Epoch 24/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.0199 - sparse_categorical_accuracy: 0.7149 - weighted_sparse_categorical_accuracy: 0.7149 - val_loss: 3.4630 - val_sparse_categorical_accuracy: 0.4225 - val_weighted_sparse_categorical_accuracy: 0.4225
# Epoch 25/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.0027 - sparse_categorical_accuracy: 0.7190 - weighted_sparse_categorical_accuracy: 0.7190 - val_loss: 3.4955 - val_sparse_categorical_accuracy: 0.4234 - val_weighted_sparse_categorical_accuracy: 0.4234
# Epoch 26/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.9858 - sparse_categorical_accuracy: 0.7239 - weighted_sparse_categorical_accuracy: 0.7239 - val_loss: 3.5474 - val_sparse_categorical_accuracy: 0.4227 - val_weighted_sparse_categorical_accuracy: 0.4227
# Epoch 27/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.9690 - sparse_categorical_accuracy: 0.7274 - weighted_sparse_categorical_accuracy: 0.7274 - val_loss: 3.5881 - val_sparse_categorical_accuracy: 0.4231 - val_weighted_sparse_categorical_accuracy: 0.4231
# Epoch 28/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.9550 - sparse_categorical_accuracy: 0.7310 - weighted_sparse_categorical_accuracy: 0.7310 - val_loss: 3.6329 - val_sparse_categorical_accuracy: 0.4228 - val_weighted_sparse_categorical_accuracy: 0.4228
# Epoch 29/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.9405 - sparse_categorical_accuracy: 0.7343 - weighted_sparse_categorical_accuracy: 0.7343 - val_loss: 3.6835 - val_sparse_categorical_accuracy: 0.4237 - val_weighted_sparse_categorical_accuracy: 0.4237
# Epoch 30/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.9267 - sparse_categorical_accuracy: 0.7384 - weighted_sparse_categorical_accuracy: 0.7384 - val_loss: 3.7001 - val_sparse_categorical_accuracy: 0.4231 - val_weighted_sparse_categorical_accuracy: 0.4231
# Epoch 31/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.9150 - sparse_categorical_accuracy: 0.7411 - weighted_sparse_categorical_accuracy: 0.7411 - val_loss: 3.7492 - val_sparse_categorical_accuracy: 0.4234 - val_weighted_sparse_categorical_accuracy: 0.4234
# Epoch 32/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.9040 - sparse_categorical_accuracy: 0.7440 - weighted_sparse_categorical_accuracy: 0.7440 - val_loss: 3.7712 - val_sparse_categorical_accuracy: 0.4230 - val_weighted_sparse_categorical_accuracy: 0.4230
# Epoch 33/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.8918 - sparse_categorical_accuracy: 0.7470 - weighted_sparse_categorical_accuracy: 0.7470 - val_loss: 3.8097 - val_sparse_categorical_accuracy: 0.4239 - val_weighted_sparse_categorical_accuracy: 0.4239
# Epoch 34/50
# 1233/1233 [==============================] - 23s 18ms/step - loss: 0.8818 - sparse_categorical_accuracy: 0.7494 - weighted_sparse_categorical_accuracy: 0.7494 - val_loss: 3.8665 - val_sparse_categorical_accuracy: 0.4228 - val_weighted_sparse_categorical_accuracy: 0.4228
# Epoch 35/50
# 1233/1233 [==============================] - 23s 18ms/step - loss: 0.8719 - sparse_categorical_accuracy: 0.7522 - weighted_sparse_categorical_accuracy: 0.7522 - val_loss: 3.8668 - val_sparse_categorical_accuracy: 0.4233 - val_weighted_sparse_categorical_accuracy: 0.4233
# Epoch 36/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.8613 - sparse_categorical_accuracy: 0.7546 - weighted_sparse_categorical_accuracy: 0.7546 - val_loss: 3.9203 - val_sparse_categorical_accuracy: 0.4236 - val_weighted_sparse_categorical_accuracy: 0.4236
# Epoch 37/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.8504 - sparse_categorical_accuracy: 0.7576 - weighted_sparse_categorical_accuracy: 0.7576 - val_loss: 3.9463 - val_sparse_categorical_accuracy: 0.4238 - val_weighted_sparse_categorical_accuracy: 0.4238
# Epoch 38/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.8443 - sparse_categorical_accuracy: 0.7588 - weighted_sparse_categorical_accuracy: 0.7588 - val_loss: 3.9766 - val_sparse_categorical_accuracy: 0.4241 - val_weighted_sparse_categorical_accuracy: 0.4241
# Epoch 39/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.8356 - sparse_categorical_accuracy: 0.7607 - weighted_sparse_categorical_accuracy: 0.7607 - val_loss: 4.0124 - val_sparse_categorical_accuracy: 0.4231 - val_weighted_sparse_categorical_accuracy: 0.4231
# Epoch 40/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.8272 - sparse_categorical_accuracy: 0.7633 - weighted_sparse_categorical_accuracy: 0.7633 - val_loss: 4.0379 - val_sparse_categorical_accuracy: 0.4242 - val_weighted_sparse_categorical_accuracy: 0.4242
# Epoch 41/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.8191 - sparse_categorical_accuracy: 0.7650 - weighted_sparse_categorical_accuracy: 0.7650 - val_loss: 4.0438 - val_sparse_categorical_accuracy: 0.4239 - val_weighted_sparse_categorical_accuracy: 0.4239
# Epoch 42/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.8111 - sparse_categorical_accuracy: 0.7671 - weighted_sparse_categorical_accuracy: 0.7671 - val_loss: 4.0627 - val_sparse_categorical_accuracy: 0.4229 - val_weighted_sparse_categorical_accuracy: 0.4229
# Epoch 43/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.8057 - sparse_categorical_accuracy: 0.7685 - weighted_sparse_categorical_accuracy: 0.7685 - val_loss: 4.1136 - val_sparse_categorical_accuracy: 0.4226 - val_weighted_sparse_categorical_accuracy: 0.4226
# Epoch 44/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.7993 - sparse_categorical_accuracy: 0.7702 - weighted_sparse_categorical_accuracy: 0.7702 - val_loss: 4.1083 - val_sparse_categorical_accuracy: 0.4238 - val_weighted_sparse_categorical_accuracy: 0.4238
# Epoch 45/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.7919 - sparse_categorical_accuracy: 0.7722 - weighted_sparse_categorical_accuracy: 0.7722 - val_loss: 4.1512 - val_sparse_categorical_accuracy: 0.4230 - val_weighted_sparse_categorical_accuracy: 0.4230
# Epoch 46/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.7859 - sparse_categorical_accuracy: 0.7734 - weighted_sparse_categorical_accuracy: 0.7734 - val_loss: 4.1681 - val_sparse_categorical_accuracy: 0.4244 - val_weighted_sparse_categorical_accuracy: 0.4244
# Epoch 47/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.7794 - sparse_categorical_accuracy: 0.7751 - weighted_sparse_categorical_accuracy: 0.7751 - val_loss: 4.1902 - val_sparse_categorical_accuracy: 0.4237 - val_weighted_sparse_categorical_accuracy: 0.4237
# Epoch 48/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.7727 - sparse_categorical_accuracy: 0.7767 - weighted_sparse_categorical_accuracy: 0.7767 - val_loss: 4.2037 - val_sparse_categorical_accuracy: 0.4240 - val_weighted_sparse_categorical_accuracy: 0.4240
# Epoch 49/50
# 1233/1233 [==============================] - 23s 18ms/step - loss: 0.7654 - sparse_categorical_accuracy: 0.7787 - weighted_sparse_categorical_accuracy: 0.7787 - val_loss: 4.2163 - val_sparse_categorical_accuracy: 0.4231 - val_weighted_sparse_categorical_accuracy: 0.4231
# Epoch 50/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 0.7609 - sparse_categorical_accuracy: 0.7794 - weighted_sparse_categorical_accuracy: 0.7794 - val_loss: 4.2303 - val_sparse_categorical_accuracy: 0.4239 - val_weighted_sparse_categorical_accuracy: 0.4239
# CPU times: user 24min 7s, sys: 2min 29s, total: 26min 36s
# Wall time: 18min 34s

# %% [markdown]
# ## Inference

# %%
model.load_weights(checkpoint_filepath)

# %%
def decode_sequence(features, words):
    output_tokens = model.predict([features, features, words])

    # Sample a token
    decoded_sentence = np.squeeze(np.argmax(output_tokens, axis=2))
    sentence = list(map(lambda x : NoteVocab.index2note[x], decoded_sentence))
    return sentence

# %%
instance_id = 46789
instance_id = 9752
print(decode_sequence(np.expand_dims(features[instance_id], axis=0), np.expand_dims(words[instance_id], axis=0)))
print(list(map(lambda x : NoteVocab.index2note[x], labels[instance_id])))
# Out:
# ['SOS', 'C5_S', 'BREAK', 'E5_S', 'C5', 'C5', 'BREAK', 'E5_S', 'E5', 'G4', 'E5', 'D#5', 'D#5', 'D#5', 'BREAK', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS']
# ['SOS', 'C5_S', 'BREAK', 'C5_S', 'C5', 'C5', 'BREAK', 'C5_S', 'C5', 'C5', 'C5', 'C5', 'C5', 'C5', 'BREAK', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS']

# %%
eval_hist = model.evaluate(
    x=[features_test, features_test, words_test],
    y=labels_test,
)
# Out:
# 444/444 [==============================] - 3s 6ms/step - loss: nan - sparse_categorical_accuracy: 0.3977 - weighted_sparse_categorical_accuracy: 0.3977

# %% [markdown]
# ## Evaluation

# %%
plt.plot(history['sparse_categorical_accuracy'], label='Training Accuracy')
plt.plot(history['val_sparse_categorical_accuracy'], label='Validation Set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

x = np.linspace(0,epochs - 1)
y = np.full(x.shape, eval_hist[1])
plt.plot(x, y, label='Test set Accuracy')

plt.title("Accuracy")
plt.legend()
plt.show()
