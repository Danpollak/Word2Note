# %% [markdown]
# <a href="https://colab.research.google.com/github/Danpollak/Word2Note/blob/master/Classification%20-%20Bidirectional%20Encoder%2BDecoder%20With%20Embbedings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
import tensorflow
import pickle as pk
from tqdm.notebook import tqdm
import statistics

import tensorflow as tf

from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Embedding, Input, Concatenate
from tensorflow import keras
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Data

# %%
class NoteLang:
    def __init__(self, name):
        self.name = name
        self.word2index = {"unk": 0, "SOS": 1, "EOS": 2, "BREAK": 3}
        self.index2word = {0: "unk", 1: "SOS", 2: "EOS", 3: "BREAK"}
        self.note2index = {"unk": 0, "SOS": 1, "EOS": 2, "BREAK": 3}
        self.index2note = {0: "unk", 1: "SOS", 2: "EOS", 3: "BREAK"}
        self.word_level2index = {"unk": 0, "SOS": 1, "EOS": 2, "BREAK": 3}
        self.index2word_level = {0: "unk", 1: "SOS", 2: "EOS", 3: "BREAK"}
        self.n_words = 4
        self.n_notes = 4
        self.n_word_level = 4

    def addSentence(self, sentence):
        for subword in sentence:
            self.addWord(subword)

    def addWord(self, word):
        subword = word[0]
        note = word[1]
        word_level = word[2]

        # insert subwords
        if subword not in self.word2index:
            self.word2index[subword] = self.n_words
            self.index2word[self.n_words] = subword
            self.n_words += 1

        # insert notes
        if note not in self.note2index:
            self.note2index[note] = self.n_notes
            self.index2note[self.n_notes] = note
            self.n_notes += 1

        # insert word level
        if word_level not in self.word_level2index:
          self.word_level2index[word_level] = self.n_word_level
          self.index2word_level[self.n_word_level] = word_level
          self.n_word_level += 1

    def check_unk(self, subword, vocabulary):
        if subword in vocabulary:
          return vocabulary[subword]
        else:
          return vocabulary["unk"]

    def sentence2index(self,sentence):
        indexed_sentence = [self.check_unk(subword, self.word2index) for subword in sentence]
        return indexed_sentence

    def note_sentence2index(self,sentence):
        indexed_sentence = [self.check_unk(note, self.note2index) for note in sentence]
        return indexed_sentence

    def word_level_sentence2index(self,sentence):
        indexed_sentence = [self.check_unk(word_level, self.word_level2index) for word_level in sentence]
        return indexed_sentence

def order_dataset(dataset, max_line_length, train=True):
    features = []
    labels = []
    words = []
    line_length = 0

    for song in tqdm(dataset):
      line = song[0]
      line_features  = []
      line_label = []
      line_word = []

      line_to_parse = [('SOS', 'SOS', 'SOS')]
      line_to_parse.extend(line)
      line_to_parse.append(('EOS', 'EOS', 'EOS'))

      for subword in line_to_parse:
        line_length+=1

        letter = subword[0]
        line_features.append(letter)

        note = subword[1]
        line_label.append(note)

        word = subword[2]
        line_word.append(word)

      # append whole line to dataset
      features.append(line_features)
      labels.append(line_label)
      words.append(line_word)

      if train:
          # get max line length
          max_line_length = max(max_line_length, line_length)
          line_length=0
          NoteVocab.addSentence(line_to_parse)

    # encode features and labels
    features = [NoteVocab.sentence2index(line) for line in tqdm(features)]
    labels = [NoteVocab.note_sentence2index(line) for line in tqdm(labels)]
    words = [NoteVocab.word_level_sentence2index(line) for line in tqdm(words)]

    # buffer features and labels
    features = [np.pad(line, (0,max_line_length - len(line)), constant_values=2) for line in tqdm(features)]
    labels = [np.pad(line, (0,max_line_length - len(line)), constant_values=2) for line in tqdm(labels)]
    words = [np.pad(line, (0,max_line_length - len(line)), constant_values=2) for line in tqdm(words)]

    # convert to numpy
    features = np.array(features)
    labels = np.array(labels)
    words = np.array(words)

    print("printing shapes for sainty check:")
    print(features.shape)
    print(labels.shape)
    print(words.shape)

    print("printing parsed data for sainty check:")
    print(features[0])
    print(labels[0])
    print(words[0])

    print("Max Line is:")
    print(max_line_length)

    return features, labels, words, max_line_length

def filter_dataset(ds):
    train_set = ds['train']
    test_set = ds['test']
    
    print("Length Before Filtering is:")
    print("Train: " + str(len(train_set)))
    print("Test: " + str(len(test_set)))

    WINDOW_SIZE = 10
    median = statistics.median([len(song[0]) for song in train_set])
    print("Median Length is: " + str(median))

    train_set = [song for song in train_set if len(song[0]) < median and len(song[0]) > (median - WINDOW_SIZE )]
    test_set = [song for song in test_set if len(song[0]) < median and len(song[0]) > (median - WINDOW_SIZE)]

    print("Length After Filtering is:")
    print("Train: " + str(len(train_set)))
    print("Test: " + str(len(test_set)))

    return train_set, test_set

# %% [markdown]
# ## Import Data

# %%
from google.colab import drive
drive.mount('/content/drive')
data_path= '/content/drive/My Drive/Colab Notebooks/DALI/ds_characters_withword_split.pickle'
NoteVocab = NoteLang('word2note')
max_line_length = 0

with open(data_path, 'rb') as pickle_file:
    ds = pk.load(pickle_file)

train_set, test_set = filter_dataset(ds)

features, labels, words, max_line_length = order_dataset(train_set, max_line_length)
features_test, words_test, labels_test, _ = order_dataset(test_set, max_line_length, False)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Length Before Filtering is:
# Train: 170725
# Test: 42681
# Median Length is: 23
# Length After Filtering is:
# Train: 56358
# Test: 14192
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# printing shapes for sainty check:
# (56358, 24)
# (56358, 24)
# (56358, 24)
# printing parsed data for sainty check:
# [ 1  4  5  6  7  8  9 10 11  6  7 12  9  5  7 13  9 14 14 12  7  2  2  2]
# [1 4 5 5 3 6 7 7 7 7 3 6 7 7 3 8 9 9 8 9 3 2 2 2]
# [1 4 4 4 3 5 5 5 5 5 3 6 6 6 3 7 7 7 7 7 3 2 2 2]
# Max Line is:
# 24
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# printing shapes for sainty check:
# (14192, 24)
# (14192, 24)
# (14192, 24)
# printing parsed data for sainty check:
# [ 1 13 21 22 10  7  6 21 22  8 14 22 19 16  7 15 25  7 18  9 10 22  7  2]
# [ 1 22 23 23 23  3 60 61 61 61 61 61 61 61  3 33 80  3 85 86 86 86  3  2]
# [  1 117 117 117 117   3   0   0   0   0   0   0   0   0   3  42  42   3
#  566 566 566 566   3   2]
# Max Line is:
# 24

# %% [markdown]
# ## Models

# %% [markdown]
# ## Sentence2Note LSTM

# %%
# Hyperparameters
vocab_size = NoteVocab.n_words
number_of_notes = NoteVocab.n_notes
word_level_vocab = NoteVocab.n_word_level
word_embedding_size = 100
LSTM_embedding_size = 100

# %%
# define note architecture
note_encoder_inputs_word = Input(shape=(max_line_length,1), dtype='float32', name="Note_Encoder_Inputs_Word")
note_decoder_inputs_word = Input(shape=(max_line_length,1), dtype='float32', name="Note_Decoder_Inputs_Word")

#######################
word_level_input = Input(shape=(max_line_length), dtype='int32', name="Word_Level_Input")
word_level_embedding_layer = Embedding(input_dim=word_level_vocab, output_dim=word_embedding_size, input_length=max_line_length)

word_level_embedding = word_level_embedding_layer(word_level_input)

decoder_input = Concatenate(axis=2)([word_level_embedding, note_decoder_inputs_word])
#######################

# defining LSTM Encoder
note_encoder_LSTM = LSTM(LSTM_embedding_size, return_state=True, name="Note_Encoder")
note_encoder_LSTM_bidrectional = Bidirectional(note_encoder_LSTM)

# getting LSTM Encoder output
#_, note_state_h_fwd, note_state_c_fwd, note_state_h_bkwd, note_state_c_bkwd = note_encoder_LSTM_bidrectional(note_encoder_inputs_word)
_ , *encoder_states = note_encoder_LSTM_bidrectional(note_encoder_inputs_word)

# defining LSTM Decoder
note_decoder_LSTM = LSTM(LSTM_embedding_size, return_state=True, return_sequences=True, name="Note_Decoder")
note_decoder_LSTM_bidrectional = Bidirectional(note_decoder_LSTM)
# getting LSTM Decoder output
note_decoder_outputs, _, _, _ ,_ = note_decoder_LSTM_bidrectional(decoder_input, initial_state=encoder_states)

# note softmax
note_decoder_dense = Dense(number_of_notes, activation='softmax', name="Note_Softmax")
note_decoder_outputs = note_decoder_dense(note_decoder_outputs)

# model definition for training
model = Model([note_encoder_inputs_word  ,note_decoder_inputs_word, word_level_input], note_decoder_outputs,name="Note_Seq2Seq")

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],weighted_metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]) 
          
model.summary()
keras.utils.plot_model(model, expand_nested=True)
# Out:
# (None, 200)
# (None, 200)
# Model: "Note_Seq2Seq"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Word_Level_Input (InputLayer)   [(None, 24)]         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 24, 100)      964100      Word_Level_Input[0][0]
# __________________________________________________________________________________________________
# Note_Decoder_Inputs_Word (Input [(None, 24, 1)]      0
# __________________________________________________________________________________________________
# Note_Encoder_Inputs_Word (Input [(None, 24, 1)]      0
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 24, 101)      0           embedding_1[0][0]
#                                                                  Note_Decoder_Inputs_Word[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) [(None, 200), (None, 81600       Note_Encoder_Inputs_Word[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) [(None, 24, 200), (N 161600      concatenate_3[0][0]
#                                                                  bidirectional_2[0][1]
#                                                                  bidirectional_2[0][2]
#                                                                  bidirectional_2[0][3]
#                                                                  bidirectional_2[0][4]
# __________________________________________________________________________________________________
# Note_Softmax (Dense)            (None, 24, 168)      33768       bidirectional_3[0][0]
# ==================================================================================================
# Total params: 1,241,068
# Trainable params: 1,241,068
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
class_weight_base = {0 : 1, 1 : 0.0001, 2 : 0.0000001, 3: 0.0001}
class_weights = {i : 200 for i in range(4, number_of_notes)}
class_weights.update(class_weight_base)

# %%
checkpoint_filepath = '/content/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

early_stop_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0.0000001, patience=10, verbose=0, mode='min',
    baseline=None, restore_best_weights=False
)

# %%
epochs=50

# %%
# %%time
# input to encoder is the feature sentence
# input to decoder is the hidden and context vector, and feature sentence
train_metadata = model.fit([features, features, words], labels,
          batch_size=32,
          epochs=epochs,
          validation_split=0.3,
          callbacks=[model_checkpoint_callback],
          #class_weight=class_weights,
          )
history = train_metadata.history
# Out:
# Epoch 1/50
# 1233/1233 [==============================] - 24s 20ms/step - loss: 2.2237 - sparse_categorical_accuracy: 0.4266 - weighted_sparse_categorical_accuracy: 0.4266 - val_loss: 2.1565 - val_sparse_categorical_accuracy: 0.4242 - val_weighted_sparse_categorical_accuracy: 0.4242
# Epoch 2/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 2.0556 - sparse_categorical_accuracy: 0.4593 - weighted_sparse_categorical_accuracy: 0.4593 - val_loss: 2.1993 - val_sparse_categorical_accuracy: 0.4269 - val_weighted_sparse_categorical_accuracy: 0.4269
# Epoch 3/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.9026 - sparse_categorical_accuracy: 0.4972 - weighted_sparse_categorical_accuracy: 0.4972 - val_loss: 2.2838 - val_sparse_categorical_accuracy: 0.4259 - val_weighted_sparse_categorical_accuracy: 0.4259
# Epoch 4/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.7941 - sparse_categorical_accuracy: 0.5185 - weighted_sparse_categorical_accuracy: 0.5185 - val_loss: 2.3276 - val_sparse_categorical_accuracy: 0.4247 - val_weighted_sparse_categorical_accuracy: 0.4247
# Epoch 5/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.7226 - sparse_categorical_accuracy: 0.5320 - weighted_sparse_categorical_accuracy: 0.5320 - val_loss: 2.3889 - val_sparse_categorical_accuracy: 0.4218 - val_weighted_sparse_categorical_accuracy: 0.4218
# Epoch 6/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.6681 - sparse_categorical_accuracy: 0.5441 - weighted_sparse_categorical_accuracy: 0.5441 - val_loss: 2.4300 - val_sparse_categorical_accuracy: 0.4225 - val_weighted_sparse_categorical_accuracy: 0.4225
# Epoch 7/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.6207 - sparse_categorical_accuracy: 0.5555 - weighted_sparse_categorical_accuracy: 0.5555 - val_loss: 2.4757 - val_sparse_categorical_accuracy: 0.4230 - val_weighted_sparse_categorical_accuracy: 0.4230
# Epoch 8/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.5759 - sparse_categorical_accuracy: 0.5675 - weighted_sparse_categorical_accuracy: 0.5675 - val_loss: 2.5287 - val_sparse_categorical_accuracy: 0.4237 - val_weighted_sparse_categorical_accuracy: 0.4237
# Epoch 9/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.5328 - sparse_categorical_accuracy: 0.5796 - weighted_sparse_categorical_accuracy: 0.5796 - val_loss: 2.5942 - val_sparse_categorical_accuracy: 0.4230 - val_weighted_sparse_categorical_accuracy: 0.4230
# Epoch 10/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.4910 - sparse_categorical_accuracy: 0.5916 - weighted_sparse_categorical_accuracy: 0.5916 - val_loss: 2.6631 - val_sparse_categorical_accuracy: 0.4233 - val_weighted_sparse_categorical_accuracy: 0.4233
# Epoch 11/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.4495 - sparse_categorical_accuracy: 0.6033 - weighted_sparse_categorical_accuracy: 0.6033 - val_loss: 2.7166 - val_sparse_categorical_accuracy: 0.4220 - val_weighted_sparse_categorical_accuracy: 0.4220
# Epoch 12/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.4108 - sparse_categorical_accuracy: 0.6135 - weighted_sparse_categorical_accuracy: 0.6135 - val_loss: 2.7843 - val_sparse_categorical_accuracy: 0.4235 - val_weighted_sparse_categorical_accuracy: 0.4235
# Epoch 13/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.3718 - sparse_categorical_accuracy: 0.6246 - weighted_sparse_categorical_accuracy: 0.6246 - val_loss: 2.8322 - val_sparse_categorical_accuracy: 0.4225 - val_weighted_sparse_categorical_accuracy: 0.4225
# Epoch 14/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.3350 - sparse_categorical_accuracy: 0.6349 - weighted_sparse_categorical_accuracy: 0.6349 - val_loss: 2.8728 - val_sparse_categorical_accuracy: 0.4229 - val_weighted_sparse_categorical_accuracy: 0.4229
# Epoch 15/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.3001 - sparse_categorical_accuracy: 0.6441 - weighted_sparse_categorical_accuracy: 0.6441 - val_loss: 2.9685 - val_sparse_categorical_accuracy: 0.4216 - val_weighted_sparse_categorical_accuracy: 0.4216
# Epoch 16/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.2663 - sparse_categorical_accuracy: 0.6529 - weighted_sparse_categorical_accuracy: 0.6529 - val_loss: 3.0057 - val_sparse_categorical_accuracy: 0.4229 - val_weighted_sparse_categorical_accuracy: 0.4229
# Epoch 17/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.2344 - sparse_categorical_accuracy: 0.6616 - weighted_sparse_categorical_accuracy: 0.6616 - val_loss: 3.0614 - val_sparse_categorical_accuracy: 0.4222 - val_weighted_sparse_categorical_accuracy: 0.4222
# Epoch 18/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.2053 - sparse_categorical_accuracy: 0.6692 - weighted_sparse_categorical_accuracy: 0.6692 - val_loss: 3.1175 - val_sparse_categorical_accuracy: 0.4220 - val_weighted_sparse_categorical_accuracy: 0.4220
# Epoch 19/50
# 1233/1233 [==============================] - 24s 20ms/step - loss: 1.1765 - sparse_categorical_accuracy: 0.6769 - weighted_sparse_categorical_accuracy: 0.6769 - val_loss: 3.1505 - val_sparse_categorical_accuracy: 0.4221 - val_weighted_sparse_categorical_accuracy: 0.4221
# Epoch 20/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.1482 - sparse_categorical_accuracy: 0.6849 - weighted_sparse_categorical_accuracy: 0.6849 - val_loss: 3.2223 - val_sparse_categorical_accuracy: 0.4222 - val_weighted_sparse_categorical_accuracy: 0.4222
# Epoch 21/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.1230 - sparse_categorical_accuracy: 0.6909 - weighted_sparse_categorical_accuracy: 0.6909 - val_loss: 3.2420 - val_sparse_categorical_accuracy: 0.4220 - val_weighted_sparse_categorical_accuracy: 0.4220
# Epoch 22/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.0985 - sparse_categorical_accuracy: 0.6969 - weighted_sparse_categorical_accuracy: 0.6969 - val_loss: 3.3102 - val_sparse_categorical_accuracy: 0.4232 - val_weighted_sparse_categorical_accuracy: 0.4232
# Epoch 23/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0745 - sparse_categorical_accuracy: 0.7036 - weighted_sparse_categorical_accuracy: 0.7036 - val_loss: 3.3625 - val_sparse_categorical_accuracy: 0.4228 - val_weighted_sparse_categorical_accuracy: 0.4228
# Epoch 24/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.0534 - sparse_categorical_accuracy: 0.7088 - weighted_sparse_categorical_accuracy: 0.7088 - val_loss: 3.4128 - val_sparse_categorical_accuracy: 0.4224 - val_weighted_sparse_categorical_accuracy: 0.4224
# Epoch 25/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0313 - sparse_categorical_accuracy: 0.7147 - weighted_sparse_categorical_accuracy: 0.7147 - val_loss: 3.4535 - val_sparse_categorical_accuracy: 0.4227 - val_weighted_sparse_categorical_accuracy: 0.4227
# Epoch 26/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0125 - sparse_categorical_accuracy: 0.7193 - weighted_sparse_categorical_accuracy: 0.7193 - val_loss: 3.5276 - val_sparse_categorical_accuracy: 0.4217 - val_weighted_sparse_categorical_accuracy: 0.4217
# Epoch 27/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 0.9934 - sparse_categorical_accuracy: 0.7241 - weighted_sparse_categorical_accuracy: 0.7241 - val_loss: 3.5602 - val_sparse_categorical_accuracy: 0.4230 - val_weighted_sparse_categorical_accuracy: 0.4230
# Epoch 28/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.9751 - sparse_categorical_accuracy: 0.7290 - weighted_sparse_categorical_accuracy: 0.7290 - val_loss: 3.5990 - val_sparse_categorical_accuracy: 0.4219 - val_weighted_sparse_categorical_accuracy: 0.4219
# Epoch 29/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.9572 - sparse_categorical_accuracy: 0.7337 - weighted_sparse_categorical_accuracy: 0.7337 - val_loss: 3.6163 - val_sparse_categorical_accuracy: 0.4223 - val_weighted_sparse_categorical_accuracy: 0.4223
# Epoch 30/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 0.9422 - sparse_categorical_accuracy: 0.7375 - weighted_sparse_categorical_accuracy: 0.7375 - val_loss: 3.6649 - val_sparse_categorical_accuracy: 0.4228 - val_weighted_sparse_categorical_accuracy: 0.4228
# Epoch 31/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.9258 - sparse_categorical_accuracy: 0.7416 - weighted_sparse_categorical_accuracy: 0.7416 - val_loss: 3.7045 - val_sparse_categorical_accuracy: 0.4236 - val_weighted_sparse_categorical_accuracy: 0.4236
# Epoch 32/50
# 1233/1233 [==============================] - 24s 20ms/step - loss: 0.9136 - sparse_categorical_accuracy: 0.7445 - weighted_sparse_categorical_accuracy: 0.7445 - val_loss: 3.7293 - val_sparse_categorical_accuracy: 0.4222 - val_weighted_sparse_categorical_accuracy: 0.4222
# Epoch 33/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.8979 - sparse_categorical_accuracy: 0.7479 - weighted_sparse_categorical_accuracy: 0.7479 - val_loss: 3.7712 - val_sparse_categorical_accuracy: 0.4229 - val_weighted_sparse_categorical_accuracy: 0.4229
# Epoch 34/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.8859 - sparse_categorical_accuracy: 0.7510 - weighted_sparse_categorical_accuracy: 0.7510 - val_loss: 3.8241 - val_sparse_categorical_accuracy: 0.4228 - val_weighted_sparse_categorical_accuracy: 0.4228
# Epoch 35/50
# 1233/1233 [==============================] - 24s 20ms/step - loss: 0.8727 - sparse_categorical_accuracy: 0.7548 - weighted_sparse_categorical_accuracy: 0.7548 - val_loss: 3.8299 - val_sparse_categorical_accuracy: 0.4219 - val_weighted_sparse_categorical_accuracy: 0.4219
# Epoch 36/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.8599 - sparse_categorical_accuracy: 0.7577 - weighted_sparse_categorical_accuracy: 0.7577 - val_loss: 3.8769 - val_sparse_categorical_accuracy: 0.4218 - val_weighted_sparse_categorical_accuracy: 0.4218
# Epoch 37/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.8502 - sparse_categorical_accuracy: 0.7603 - weighted_sparse_categorical_accuracy: 0.7603 - val_loss: 3.9438 - val_sparse_categorical_accuracy: 0.4219 - val_weighted_sparse_categorical_accuracy: 0.4219
# Epoch 38/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.8380 - sparse_categorical_accuracy: 0.7633 - weighted_sparse_categorical_accuracy: 0.7633 - val_loss: 3.9686 - val_sparse_categorical_accuracy: 0.4233 - val_weighted_sparse_categorical_accuracy: 0.4233
# Epoch 39/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.8287 - sparse_categorical_accuracy: 0.7657 - weighted_sparse_categorical_accuracy: 0.7657 - val_loss: 3.9856 - val_sparse_categorical_accuracy: 0.4224 - val_weighted_sparse_categorical_accuracy: 0.4224
# Epoch 40/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.8184 - sparse_categorical_accuracy: 0.7677 - weighted_sparse_categorical_accuracy: 0.7677 - val_loss: 4.0269 - val_sparse_categorical_accuracy: 0.4234 - val_weighted_sparse_categorical_accuracy: 0.4234
# Epoch 41/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.8063 - sparse_categorical_accuracy: 0.7712 - weighted_sparse_categorical_accuracy: 0.7712 - val_loss: 4.0513 - val_sparse_categorical_accuracy: 0.4226 - val_weighted_sparse_categorical_accuracy: 0.4226
# Epoch 42/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.7985 - sparse_categorical_accuracy: 0.7735 - weighted_sparse_categorical_accuracy: 0.7735 - val_loss: 4.0926 - val_sparse_categorical_accuracy: 0.4223 - val_weighted_sparse_categorical_accuracy: 0.4223
# Epoch 43/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.7890 - sparse_categorical_accuracy: 0.7750 - weighted_sparse_categorical_accuracy: 0.7750 - val_loss: 4.1053 - val_sparse_categorical_accuracy: 0.4229 - val_weighted_sparse_categorical_accuracy: 0.4229
# Epoch 44/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.7801 - sparse_categorical_accuracy: 0.7777 - weighted_sparse_categorical_accuracy: 0.7777 - val_loss: 4.1368 - val_sparse_categorical_accuracy: 0.4226 - val_weighted_sparse_categorical_accuracy: 0.4226
# Epoch 45/50
# 1233/1233 [==============================] - 25s 20ms/step - loss: 0.7714 - sparse_categorical_accuracy: 0.7801 - weighted_sparse_categorical_accuracy: 0.7801 - val_loss: 4.1442 - val_sparse_categorical_accuracy: 0.4225 - val_weighted_sparse_categorical_accuracy: 0.4225
# Epoch 46/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 0.7637 - sparse_categorical_accuracy: 0.7814 - weighted_sparse_categorical_accuracy: 0.7814 - val_loss: 4.1848 - val_sparse_categorical_accuracy: 0.4225 - val_weighted_sparse_categorical_accuracy: 0.4225
# Epoch 47/50
# 1233/1233 [==============================] - 24s 20ms/step - loss: 0.7541 - sparse_categorical_accuracy: 0.7839 - weighted_sparse_categorical_accuracy: 0.7839 - val_loss: 4.2234 - val_sparse_categorical_accuracy: 0.4228 - val_weighted_sparse_categorical_accuracy: 0.4228
# Epoch 48/50
# 1233/1233 [==============================] - 24s 20ms/step - loss: 0.7478 - sparse_categorical_accuracy: 0.7854 - weighted_sparse_categorical_accuracy: 0.7854 - val_loss: 4.2355 - val_sparse_categorical_accuracy: 0.4225 - val_weighted_sparse_categorical_accuracy: 0.4225
# Epoch 49/50
# 1233/1233 [==============================] - 24s 20ms/step - loss: 0.7408 - sparse_categorical_accuracy: 0.7869 - weighted_sparse_categorical_accuracy: 0.7869 - val_loss: 4.2845 - val_sparse_categorical_accuracy: 0.4229 - val_weighted_sparse_categorical_accuracy: 0.4229
# Epoch 50/50
# 1233/1233 [==============================] - 24s 20ms/step - loss: 0.7349 - sparse_categorical_accuracy: 0.7887 - weighted_sparse_categorical_accuracy: 0.7887 - val_loss: 4.2872 - val_sparse_categorical_accuracy: 0.4225 - val_weighted_sparse_categorical_accuracy: 0.4225
# CPU times: user 25min 56s, sys: 2min 16s, total: 28min 13s
# Wall time: 19min 51s

# %% [markdown]
# ## Inference

# %%
model.load_weights(checkpoint_filepath)
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.embeddings.Embedding object at 0x7efe95a2f358> and <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7efe95a2f0b8>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.wrappers.Bidirectional object at 0x7efe95a39940> and <tensorflow.python.keras.layers.merge.Concatenate object at 0x7efe95a2fb00>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.recurrent_v2.LSTM object at 0x7efe9598ceb8> and <tensorflow.python.keras.layers.merge.Concatenate object at 0x7efe95995710>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.core.Dense object at 0x7efe955c31d0> and <tensorflow.python.keras.layers.merge.Concatenate object at 0x7efe95a3b7f0>).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-3f92b3ade396> in <module>()
# ----> 1 model.load_weights(checkpoint_filepath)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2180         save_format = 'h5'
#    2181     if save_format == 'tf':
# -> 2182       status = self._trackable_saver.restore(filepath, options)
#    2183       if by_name:
#    2184         raise NotImplementedError(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/util.py in restore(self, save_path, options)
#    1318         options=options)
#    1319     base.CheckpointPosition(
# -> 1320         checkpoint=checkpoint, proto_id=0).restore(self._graph_view.root)
#    1321     load_status = CheckpointLoadStatus(
#    1322         checkpoint,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in restore(self, trackable)
#     207         # This object's correspondence with a checkpointed object is new, so
#     208         # process deferred restorations for it and its dependencies.
# --> 209         restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     210         if restore_ops:
#     211           self._checkpoint.new_restore_ops(restore_ops)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in _restore_from_checkpoint_position(self, checkpoint_position)
#     906           ._single_restoration_from_checkpoint_position(
#     907               checkpoint_position=current_position,
# --> 908               visit_queue=visit_queue))
#     909       restore_ops.extend(new_restore_ops)
#     910       tensor_saveables.update(new_tensor_saveables)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in _single_restoration_from_checkpoint_position(self, checkpoint_position, visit_queue)
#     941                                                []).append(child_position)
#     942       else:
# --> 943         if child_position.bind_object(trackable=local_object):
#     944           # This object's correspondence is new, so dependencies need to be
#     945           # visited. Delay doing it so that we get a breadth-first dependency
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in bind_object(self, trackable)
#     256                   proto_id=slot_restoration.slot_variable_id),
#     257               variable=trackable,
# --> 258               slot_name=slot_restoration.slot_name)
#     259       return True  # New assignment
#     260     else:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in _create_or_restore_slot_variable(self, slot_variable_position, slot_name, variable)
#    1234       # If we've either made this slot variable, or if we've pulled out an
#    1235       # existing slot variable, we should restore it.
# -> 1236       slot_variable_position.restore(slot_variable)
#    1237     else:
#    1238       # We didn't make the slot variable. Defer restoring until it gets created
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in restore(self, trackable)
#     207         # This object's correspondence with a checkpointed object is new, so
#     208         # process deferred restorations for it and its dependencies.
# --> 209         restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     210         if restore_ops:
#     211           self._checkpoint.new_restore_ops(restore_ops)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in _restore_from_checkpoint_position(self, checkpoint_position)
#     912     restore_ops.extend(
#     913         current_position.checkpoint.restore_saveables(
# --> 914             tensor_saveables, python_saveables))
#     915     return restore_ops
#     916
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/util.py in restore_saveables(self, tensor_saveables, python_saveables)
#     295              "expecting %s") % (tensor_saveables.keys(), validated_names))
#     296       new_restore_ops = functional_saver.MultiDeviceSaver(
# --> 297           validated_saveables).restore(self.save_path_tensor, self.options)
#     298       if not context.executing_eagerly():
#     299         for name, restore_op in sorted(new_restore_ops.items()):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saving/functional_saver.py in restore(self, file_prefix, options)
#     338       restore_ops = tf_function_restore()
#     339     else:
# --> 340       restore_ops = restore_fn()
#     341
#     342     for callback in self._after_restore_callbacks:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saving/functional_saver.py in restore_fn()
#     314       for device, saver in sorted(self._single_device_savers.items()):
#     315         with ops.device(device):
# --> 316           restore_ops.update(saver.restore(file_prefix, options))
#     317
#     318       return restore_ops
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saving/functional_saver.py in restore(self, file_prefix, options)
#     109                                           structured_restored_tensors):
#     110       restore_ops[saveable.name] = saveable.restore(
# --> 111           restored_tensors, restored_shapes=None)
#     112     return restore_ops
#     113
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saving/saveable_object_util.py in restore(self, restored_tensors, restored_shapes)
#     125       restored_tensor = array_ops.identity(restored_tensor)
#     126       return resource_variable_ops.shape_safe_assign_variable_handle(
# --> 127           self.handle_op, self._var_shape, restored_tensor)
#     128
#     129
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py in shape_safe_assign_variable_handle(handle, shape, value, name)
#     309   with _handle_graph(handle):
#     310     value_tensor = ops.convert_to_tensor(value)
# --> 311   shape.assert_is_compatible_with(value_tensor.shape)
#     312   return gen_resource_variable_ops.assign_variable_op(handle,
#     313                                                       value_tensor,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/tensor_shape.py in assert_is_compatible_with(self, other)
#    1132     """
#    1133     if not self.is_compatible_with(other):
# -> 1134       raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#    1135
#    1136   def most_specific_compatible_shape(self, other):
#
# ValueError: Shapes (200, 168) and (100, 168) are incompatible

# %%
def decode_sequence(features, words):
    output_tokens = model.predict([features, features, words])

    # Sample a token
    decoded_sentence = np.squeeze(np.argmax(output_tokens, axis=2))
    sentence = list(map(lambda x : NoteVocab.index2note[x], decoded_sentence))
    return sentence

# %%
instance_id = 46789
instance_id = 9752
print(decode_sequence(np.expand_dims(features[instance_id], axis=0), np.expand_dims(words[instance_id], axis=0)))
print(list(map(lambda x : NoteVocab.index2note[x], labels[instance_id])))
# Out:
# ['SOS', 'A#4_S', 'BREAK', 'C5_S', 'C5', 'C5', 'BREAK', 'C5_S', 'C5', 'C5', 'C5', 'C5', 'C5', 'C5', 'BREAK', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS']
# ['SOS', 'C5_S', 'BREAK', 'C5_S', 'C5', 'C5', 'BREAK', 'C5_S', 'C5', 'C5', 'C5', 'C5', 'C5', 'C5', 'BREAK', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS']

# %%
eval_hist = model.evaluate(
    x=[features_test, features_test, words_test],
    y=labels_test,
)
# Out:
# 444/444 [==============================] - 2s 5ms/step - loss: nan - sparse_categorical_accuracy: 0.3958 - weighted_sparse_categorical_accuracy: 0.3958

# %% [markdown]
# ## Evaluation

# %%
plt.plot(history['sparse_categorical_accuracy'], label='Training Accuracy')
plt.plot(history['val_sparse_categorical_accuracy'], label='Validation Set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

x = np.linspace(0,epochs - 1)
y = np.full(x.shape, eval_hist[1])
plt.plot(x, y, label='Test set Accuracy')

plt.title("Accuracy")
plt.legend()
plt.show()
