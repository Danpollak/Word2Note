# %% [markdown]
# <a href="https://colab.research.google.com/github/Danpollak/Word2Note/blob/master/Classification%20-%20With%20Embbedings%20%2B%20Custom%20Loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
import tensorflow
import pickle as pk
from tqdm.notebook import tqdm
import statistics

import tensorflow as tf

from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Embedding, Input, Concatenate
from tensorflow import keras
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Data

# %%
class NoteLang:
    def __init__(self, name):
        self.name = name
        self.word2index = {"unk": 0, "SOS": 1, "EOS": 2, "BREAK": 3}
        self.index2word = {0: "unk", 1: "SOS", 2: "EOS", 3: "BREAK"}
        self.note2index = {"unk": 0, "SOS": 1, "EOS": 2, "BREAK": 3}
        self.index2note = {0: "unk", 1: "SOS", 2: "EOS", 3: "BREAK"}
        self.word_level2index = {"unk": 0, "SOS": 1, "EOS": 2, "BREAK": 3}
        self.index2word_level = {0: "unk", 1: "SOS", 2: "EOS", 3: "BREAK"}
        self.n_words = 4
        self.n_notes = 4
        self.n_word_level = 4

    def addSentence(self, sentence):
        for subword in sentence:
            self.addWord(subword)

    def addWord(self, word):
        subword = word[0]
        note = word[1]
        word_level = word[2]

        # insert subwords
        if subword not in self.word2index:
            self.word2index[subword] = self.n_words
            self.index2word[self.n_words] = subword
            self.n_words += 1

        # insert notes
        if note not in self.note2index:
            self.note2index[note] = self.n_notes
            self.index2note[self.n_notes] = note
            self.n_notes += 1

        # insert word level
        if word_level not in self.word_level2index:
          self.word_level2index[word_level] = self.n_word_level
          self.index2word_level[self.n_word_level] = word_level
          self.n_word_level += 1

    def check_unk(self, subword, vocabulary):
        if subword in vocabulary:
          return vocabulary[subword]
        else:
          return vocabulary["unk"]

    def sentence2index(self,sentence):
        indexed_sentence = [self.check_unk(subword, self.word2index) for subword in sentence]
        return indexed_sentence

    def note_sentence2index(self,sentence):
        indexed_sentence = [self.check_unk(note, self.note2index) for note in sentence]
        return indexed_sentence

    def word_level_sentence2index(self,sentence):
        indexed_sentence = [self.check_unk(word_level, self.word_level2index) for word_level in sentence]
        return indexed_sentence

def order_dataset(dataset, max_line_length, train=True):
    features = []
    labels = []
    words = []
    line_length = 0

    for song in tqdm(dataset):
      line = song[0]
      line_features  = []
      line_label = []
      line_word = []

      line_to_parse = [('SOS', 'SOS', 'SOS')]
      line_to_parse.extend(line)
      line_to_parse.append(('EOS', 'EOS', 'EOS'))

      for subword in line_to_parse:
        line_length+=1

        letter = subword[0]
        line_features.append(letter)

        note = subword[1]
        line_label.append(note)

        word = subword[2]
        line_word.append(word)

      # append whole line to dataset
      features.append(line_features)
      labels.append(line_label)
      words.append(line_word)

      if train:
          # get max line length
          max_line_length = max(max_line_length, line_length)
          line_length=0
          NoteVocab.addSentence(line_to_parse)

    # encode features and labels
    features = [NoteVocab.sentence2index(line) for line in tqdm(features)]
    labels = [NoteVocab.note_sentence2index(line) for line in tqdm(labels)]
    words = [NoteVocab.word_level_sentence2index(line) for line in tqdm(words)]

    # buffer features and labels
    features = [np.pad(line, (0,max_line_length - len(line)), constant_values=2) for line in tqdm(features)]
    labels = [np.pad(line, (0,max_line_length - len(line)), constant_values=2) for line in tqdm(labels)]
    words = [np.pad(line, (0,max_line_length - len(line)), constant_values=2) for line in tqdm(words)]

    # convert to numpy
    features = np.array(features)
    labels = np.array(labels)
    words = np.array(words)

    print("printing shapes for sainty check:")
    print(features.shape)
    print(labels.shape)
    print(words.shape)

    print("printing parsed data for sainty check:")
    print(features[0])
    print(labels[0])
    print(words[0])

    print("Max Line is:")
    print(max_line_length)

    return features, labels, words, max_line_length

def filter_dataset(ds):
    train_set = ds['train']
    test_set = ds['test']
    
    print("Length Before Filtering is:")
    print("Train: " + str(len(train_set)))
    print("Test: " + str(len(test_set)))

    WINDOW_SIZE = 10
    median = statistics.median([len(song[0]) for song in train_set])
    print("Median Length is: " + str(median))

    train_set = [song for song in train_set if len(song[0]) < median and len(song[0]) > (median - WINDOW_SIZE )]
    test_set = [song for song in test_set if len(song[0]) < median and len(song[0]) > (median - WINDOW_SIZE)]

    print("Length After Filtering is:")
    print("Train: " + str(len(train_set)))
    print("Test: " + str(len(test_set)))

    return train_set, test_set

# %% [markdown]
# ## Import Data

# %%
from google.colab import drive
drive.mount('/content/drive')
data_path= '/content/drive/My Drive/Colab Notebooks/DALI/ds_characters_withword_split.pickle'
NoteVocab = NoteLang('word2note')
max_line_length = 0

with open(data_path, 'rb') as pickle_file:
    ds = pk.load(pickle_file)

train_set, test_set = filter_dataset(ds)

features, labels, words, max_line_length = order_dataset(train_set, max_line_length)
features_test, words_test, labels_test, _ = order_dataset(test_set, max_line_length, False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Length Before Filtering is:
# Train: 170725
# Test: 42681
# Median Length is: 23
# Length After Filtering is:
# Train: 56358
# Test: 14192
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56358.0), HTML(value='')))
# printing shapes for sainty check:
# (56358, 24)
# (56358, 24)
# (56358, 24)
# printing parsed data for sainty check:
# [ 1  4  5  6  7  8  9 10 11  6  7 12  9  5  7 13  9 14 14 12  7  2  2  2]
# [1 4 5 5 3 6 7 7 7 7 3 6 7 7 3 8 9 9 8 9 3 2 2 2]
# [1 4 4 4 3 5 5 5 5 5 3 6 6 6 3 7 7 7 7 7 3 2 2 2]
# Max Line is:
# 24
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14192.0), HTML(value='')))
# printing shapes for sainty check:
# (14192, 24)
# (14192, 24)
# (14192, 24)
# printing parsed data for sainty check:
# [ 1 13 21 22 10  7  6 21 22  8 14 22 19 16  7 15 25  7 18  9 10 22  7  2]
# [ 1 22 23 23 23  3 60 61 61 61 61 61 61 61  3 33 80  3 85 86 86 86  3  2]
# [  1 117 117 117 117   3   0   0   0   0   0   0   0   0   3  42  42   3
#  566 566 566 566   3   2]
# Max Line is:
# 24

# %% [markdown]
# ## Models

# %% [markdown]
# ## Sentence2Note LSTM

# %%
# Hyperparameters
vocab_size = NoteVocab.n_words
number_of_notes = NoteVocab.n_notes
word_level_vocab = NoteVocab.n_word_level
word_embedding_size = 100
LSTM_embedding_size = 100

# %%
# define note architecture
note_encoder_inputs_word = Input(shape=(max_line_length,1), dtype='float32', name="Note_Encoder_Inputs_Word")
note_decoder_inputs_word = Input(shape=(max_line_length,1), dtype='float32', name="Note_Decoder_Inputs_Word")

#######################
word_level_input = Input(shape=(max_line_length), dtype='int32', name="Word_Level_Input")
word_level_embedding_layer = Embedding(input_dim=word_level_vocab, output_dim=word_embedding_size, input_length=max_line_length)

word_level_embedding = word_level_embedding_layer(word_level_input)

decoder_input = Concatenate(axis=2)([word_level_embedding, note_decoder_inputs_word])
#######################

# defining LSTM Encoder
note_encoder_LSTM = LSTM(LSTM_embedding_size, return_state=True, name="Note_Encoder")
# getting LSTM Encoder output
_, note_state_h, note_state_c = note_encoder_LSTM(note_encoder_inputs_word)
note_encoder_states = [note_state_h, note_state_c]

# defining LSTM Decoder
note_decoder_LSTM = LSTM(LSTM_embedding_size, return_state=True, return_sequences=True, name="Note_Decoder")
# getting LSTM Decoder output
note_decoder_outputs, _, _ = note_decoder_LSTM(decoder_input, initial_state=note_encoder_states)

# note softmax
note_decoder_dense = Dense(number_of_notes, activation='softmax', name="Note_Softmax")
note_decoder_outputs = note_decoder_dense(note_decoder_outputs)

# model definition for training
model = Model([note_encoder_inputs_word  ,note_decoder_inputs_word, word_level_input], note_decoder_outputs,name="Note_Seq2Seq")

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],weighted_metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]) 
          
model.summary()
keras.utils.plot_model(model, expand_nested=True)
# Out:
# Model: "Note_Seq2Seq"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Word_Level_Input (InputLayer)   [(None, 24)]         0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 24, 100)      964100      Word_Level_Input[0][0]
# __________________________________________________________________________________________________
# Note_Decoder_Inputs_Word (Input [(None, 24, 1)]      0
# __________________________________________________________________________________________________
# Note_Encoder_Inputs_Word (Input [(None, 24, 1)]      0
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 24, 101)      0           embedding_4[0][0]
#                                                                  Note_Decoder_Inputs_Word[0][0]
# __________________________________________________________________________________________________
# Note_Encoder (LSTM)             [(None, 100), (None, 40800       Note_Encoder_Inputs_Word[0][0]
# __________________________________________________________________________________________________
# Note_Decoder (LSTM)             [(None, 24, 100), (N 80800       concatenate_4[0][0]
#                                                                  Note_Encoder[0][1]
#                                                                  Note_Encoder[0][2]
# __________________________________________________________________________________________________
# Note_Softmax (Dense)            (None, 24, 168)      16968       Note_Decoder[0][0]
# ==================================================================================================
# Total params: 1,102,668
# Trainable params: 1,102,668
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
class_weight_base = {0 : 1, 1 : 0.0001, 2 : 0.0000001, 3: 0.0001}
class_weights = {i : 200 for i in range(4, number_of_notes)}
class_weights.update(class_weight_base)

# %%
checkpoint_filepath = '/content/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

early_stop_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0.0000001, patience=10, verbose=0, mode='min',
    baseline=None, restore_best_weights=False
)

# %%
epochs=50

# %%
# %%time
# input to encoder is the feature sentence
# input to decoder is the hidden and context vector, and feature sentence
train_metadata = model.fit([features, features, words], labels,
          batch_size=32,
          epochs=epochs,
          validation_split=0.3,
          callbacks=[model_checkpoint_callback],
          #class_weight=class_weights,
          )
history = train_metadata.history
# Out:
# Epoch 1/50
# 1233/1233 [==============================] - 22s 18ms/step - loss: 1.9325 - sparse_categorical_accuracy: 0.4923 - weighted_sparse_categorical_accuracy: 0.4923 - val_loss: 2.2805 - val_sparse_categorical_accuracy: 0.4224 - val_weighted_sparse_categorical_accuracy: 0.4224
# Epoch 2/50
# 1233/1233 [==============================] - 23s 18ms/step - loss: 1.8276 - sparse_categorical_accuracy: 0.5141 - weighted_sparse_categorical_accuracy: 0.5141 - val_loss: 2.3124 - val_sparse_categorical_accuracy: 0.4263 - val_weighted_sparse_categorical_accuracy: 0.4263
# Epoch 3/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.7613 - sparse_categorical_accuracy: 0.5276 - weighted_sparse_categorical_accuracy: 0.5276 - val_loss: 2.3615 - val_sparse_categorical_accuracy: 0.4230 - val_weighted_sparse_categorical_accuracy: 0.4230
# Epoch 4/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.7106 - sparse_categorical_accuracy: 0.5378 - weighted_sparse_categorical_accuracy: 0.5378 - val_loss: 2.3970 - val_sparse_categorical_accuracy: 0.4243 - val_weighted_sparse_categorical_accuracy: 0.4243
# Epoch 5/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.6678 - sparse_categorical_accuracy: 0.5473 - weighted_sparse_categorical_accuracy: 0.5473 - val_loss: 2.4651 - val_sparse_categorical_accuracy: 0.4235 - val_weighted_sparse_categorical_accuracy: 0.4235
# Epoch 6/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.6300 - sparse_categorical_accuracy: 0.5567 - weighted_sparse_categorical_accuracy: 0.5567 - val_loss: 2.4871 - val_sparse_categorical_accuracy: 0.4235 - val_weighted_sparse_categorical_accuracy: 0.4235
# Epoch 7/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.5970 - sparse_categorical_accuracy: 0.5644 - weighted_sparse_categorical_accuracy: 0.5644 - val_loss: 2.5448 - val_sparse_categorical_accuracy: 0.4224 - val_weighted_sparse_categorical_accuracy: 0.4224
# Epoch 8/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.5669 - sparse_categorical_accuracy: 0.5717 - weighted_sparse_categorical_accuracy: 0.5717 - val_loss: 2.5710 - val_sparse_categorical_accuracy: 0.4234 - val_weighted_sparse_categorical_accuracy: 0.4234
# Epoch 9/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.5386 - sparse_categorical_accuracy: 0.5787 - weighted_sparse_categorical_accuracy: 0.5787 - val_loss: 2.6356 - val_sparse_categorical_accuracy: 0.4235 - val_weighted_sparse_categorical_accuracy: 0.4235
# Epoch 10/50
# 1233/1233 [==============================] - 23s 18ms/step - loss: 1.5120 - sparse_categorical_accuracy: 0.5864 - weighted_sparse_categorical_accuracy: 0.5864 - val_loss: 2.6587 - val_sparse_categorical_accuracy: 0.4230 - val_weighted_sparse_categorical_accuracy: 0.4230
# Epoch 11/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.4885 - sparse_categorical_accuracy: 0.5926 - weighted_sparse_categorical_accuracy: 0.5926 - val_loss: 2.6941 - val_sparse_categorical_accuracy: 0.4222 - val_weighted_sparse_categorical_accuracy: 0.4222
# Epoch 12/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.4631 - sparse_categorical_accuracy: 0.5994 - weighted_sparse_categorical_accuracy: 0.5994 - val_loss: 2.7587 - val_sparse_categorical_accuracy: 0.4219 - val_weighted_sparse_categorical_accuracy: 0.4219
# Epoch 13/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.4396 - sparse_categorical_accuracy: 0.6059 - weighted_sparse_categorical_accuracy: 0.6059 - val_loss: 2.8151 - val_sparse_categorical_accuracy: 0.4235 - val_weighted_sparse_categorical_accuracy: 0.4235
# Epoch 14/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.4182 - sparse_categorical_accuracy: 0.6114 - weighted_sparse_categorical_accuracy: 0.6114 - val_loss: 2.8151 - val_sparse_categorical_accuracy: 0.4227 - val_weighted_sparse_categorical_accuracy: 0.4227
# Epoch 15/50
# 1233/1233 [==============================] - 23s 18ms/step - loss: 1.3971 - sparse_categorical_accuracy: 0.6171 - weighted_sparse_categorical_accuracy: 0.6171 - val_loss: 2.8502 - val_sparse_categorical_accuracy: 0.4221 - val_weighted_sparse_categorical_accuracy: 0.4221
# Epoch 16/50
# 1233/1233 [==============================] - 23s 18ms/step - loss: 1.3758 - sparse_categorical_accuracy: 0.6236 - weighted_sparse_categorical_accuracy: 0.6236 - val_loss: 2.8778 - val_sparse_categorical_accuracy: 0.4230 - val_weighted_sparse_categorical_accuracy: 0.4230
# Epoch 17/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.3562 - sparse_categorical_accuracy: 0.6287 - weighted_sparse_categorical_accuracy: 0.6287 - val_loss: 2.9231 - val_sparse_categorical_accuracy: 0.4228 - val_weighted_sparse_categorical_accuracy: 0.4228
# Epoch 18/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.3379 - sparse_categorical_accuracy: 0.6339 - weighted_sparse_categorical_accuracy: 0.6339 - val_loss: 2.9660 - val_sparse_categorical_accuracy: 0.4227 - val_weighted_sparse_categorical_accuracy: 0.4227
# Epoch 19/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.3200 - sparse_categorical_accuracy: 0.6388 - weighted_sparse_categorical_accuracy: 0.6388 - val_loss: 2.9979 - val_sparse_categorical_accuracy: 0.4229 - val_weighted_sparse_categorical_accuracy: 0.4229
# Epoch 20/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.3015 - sparse_categorical_accuracy: 0.6439 - weighted_sparse_categorical_accuracy: 0.6439 - val_loss: 3.0135 - val_sparse_categorical_accuracy: 0.4221 - val_weighted_sparse_categorical_accuracy: 0.4221
# Epoch 21/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.2853 - sparse_categorical_accuracy: 0.6486 - weighted_sparse_categorical_accuracy: 0.6486 - val_loss: 3.0827 - val_sparse_categorical_accuracy: 0.4220 - val_weighted_sparse_categorical_accuracy: 0.4220
# Epoch 22/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.2683 - sparse_categorical_accuracy: 0.6529 - weighted_sparse_categorical_accuracy: 0.6529 - val_loss: 3.0905 - val_sparse_categorical_accuracy: 0.4221 - val_weighted_sparse_categorical_accuracy: 0.4221
# Epoch 23/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.2529 - sparse_categorical_accuracy: 0.6566 - weighted_sparse_categorical_accuracy: 0.6566 - val_loss: 3.1481 - val_sparse_categorical_accuracy: 0.4224 - val_weighted_sparse_categorical_accuracy: 0.4224
# Epoch 24/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.2377 - sparse_categorical_accuracy: 0.6610 - weighted_sparse_categorical_accuracy: 0.6610 - val_loss: 3.1770 - val_sparse_categorical_accuracy: 0.4225 - val_weighted_sparse_categorical_accuracy: 0.4225
# Epoch 25/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.2232 - sparse_categorical_accuracy: 0.6647 - weighted_sparse_categorical_accuracy: 0.6647 - val_loss: 3.1835 - val_sparse_categorical_accuracy: 0.4228 - val_weighted_sparse_categorical_accuracy: 0.4228
# Epoch 26/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.2089 - sparse_categorical_accuracy: 0.6683 - weighted_sparse_categorical_accuracy: 0.6683 - val_loss: 3.2438 - val_sparse_categorical_accuracy: 0.4217 - val_weighted_sparse_categorical_accuracy: 0.4217
# Epoch 27/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.1944 - sparse_categorical_accuracy: 0.6724 - weighted_sparse_categorical_accuracy: 0.6724 - val_loss: 3.2640 - val_sparse_categorical_accuracy: 0.4231 - val_weighted_sparse_categorical_accuracy: 0.4231
# Epoch 28/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.1814 - sparse_categorical_accuracy: 0.6756 - weighted_sparse_categorical_accuracy: 0.6756 - val_loss: 3.2801 - val_sparse_categorical_accuracy: 0.4220 - val_weighted_sparse_categorical_accuracy: 0.4220
# Epoch 29/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.1711 - sparse_categorical_accuracy: 0.6789 - weighted_sparse_categorical_accuracy: 0.6789 - val_loss: 3.3218 - val_sparse_categorical_accuracy: 0.4217 - val_weighted_sparse_categorical_accuracy: 0.4217
# Epoch 30/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.1570 - sparse_categorical_accuracy: 0.6821 - weighted_sparse_categorical_accuracy: 0.6821 - val_loss: 3.3302 - val_sparse_categorical_accuracy: 0.4217 - val_weighted_sparse_categorical_accuracy: 0.4217
# Epoch 31/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.1444 - sparse_categorical_accuracy: 0.6858 - weighted_sparse_categorical_accuracy: 0.6858 - val_loss: 3.4052 - val_sparse_categorical_accuracy: 0.4221 - val_weighted_sparse_categorical_accuracy: 0.4221
# Epoch 32/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.1330 - sparse_categorical_accuracy: 0.6886 - weighted_sparse_categorical_accuracy: 0.6886 - val_loss: 3.3874 - val_sparse_categorical_accuracy: 0.4221 - val_weighted_sparse_categorical_accuracy: 0.4221
# Epoch 33/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.1207 - sparse_categorical_accuracy: 0.6921 - weighted_sparse_categorical_accuracy: 0.6921 - val_loss: 3.4368 - val_sparse_categorical_accuracy: 0.4220 - val_weighted_sparse_categorical_accuracy: 0.4220
# Epoch 34/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.1101 - sparse_categorical_accuracy: 0.6945 - weighted_sparse_categorical_accuracy: 0.6945 - val_loss: 3.4725 - val_sparse_categorical_accuracy: 0.4215 - val_weighted_sparse_categorical_accuracy: 0.4215
# Epoch 35/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0994 - sparse_categorical_accuracy: 0.6973 - weighted_sparse_categorical_accuracy: 0.6973 - val_loss: 3.5000 - val_sparse_categorical_accuracy: 0.4223 - val_weighted_sparse_categorical_accuracy: 0.4223
# Epoch 36/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0886 - sparse_categorical_accuracy: 0.6999 - weighted_sparse_categorical_accuracy: 0.6999 - val_loss: 3.4860 - val_sparse_categorical_accuracy: 0.4227 - val_weighted_sparse_categorical_accuracy: 0.4227
# Epoch 37/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0798 - sparse_categorical_accuracy: 0.7023 - weighted_sparse_categorical_accuracy: 0.7023 - val_loss: 3.5204 - val_sparse_categorical_accuracy: 0.4221 - val_weighted_sparse_categorical_accuracy: 0.4221
# Epoch 38/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0696 - sparse_categorical_accuracy: 0.7050 - weighted_sparse_categorical_accuracy: 0.7050 - val_loss: 3.5346 - val_sparse_categorical_accuracy: 0.4218 - val_weighted_sparse_categorical_accuracy: 0.4218
# Epoch 39/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0605 - sparse_categorical_accuracy: 0.7073 - weighted_sparse_categorical_accuracy: 0.7073 - val_loss: 3.5480 - val_sparse_categorical_accuracy: 0.4226 - val_weighted_sparse_categorical_accuracy: 0.4226
# Epoch 40/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0511 - sparse_categorical_accuracy: 0.7097 - weighted_sparse_categorical_accuracy: 0.7097 - val_loss: 3.5895 - val_sparse_categorical_accuracy: 0.4214 - val_weighted_sparse_categorical_accuracy: 0.4214
# Epoch 41/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0429 - sparse_categorical_accuracy: 0.7121 - weighted_sparse_categorical_accuracy: 0.7121 - val_loss: 3.6406 - val_sparse_categorical_accuracy: 0.4223 - val_weighted_sparse_categorical_accuracy: 0.4223
# Epoch 42/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0358 - sparse_categorical_accuracy: 0.7133 - weighted_sparse_categorical_accuracy: 0.7133 - val_loss: 3.6698 - val_sparse_categorical_accuracy: 0.4226 - val_weighted_sparse_categorical_accuracy: 0.4226
# Epoch 43/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0238 - sparse_categorical_accuracy: 0.7166 - weighted_sparse_categorical_accuracy: 0.7166 - val_loss: 3.6569 - val_sparse_categorical_accuracy: 0.4216 - val_weighted_sparse_categorical_accuracy: 0.4216
# Epoch 44/50
# 1233/1233 [==============================] - 24s 19ms/step - loss: 1.0162 - sparse_categorical_accuracy: 0.7184 - weighted_sparse_categorical_accuracy: 0.7184 - val_loss: 3.6887 - val_sparse_categorical_accuracy: 0.4223 - val_weighted_sparse_categorical_accuracy: 0.4223
# Epoch 45/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0072 - sparse_categorical_accuracy: 0.7212 - weighted_sparse_categorical_accuracy: 0.7212 - val_loss: 3.7049 - val_sparse_categorical_accuracy: 0.4221 - val_weighted_sparse_categorical_accuracy: 0.4221
# Epoch 46/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 1.0012 - sparse_categorical_accuracy: 0.7222 - weighted_sparse_categorical_accuracy: 0.7222 - val_loss: 3.7470 - val_sparse_categorical_accuracy: 0.4221 - val_weighted_sparse_categorical_accuracy: 0.4221
# Epoch 47/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 0.9936 - sparse_categorical_accuracy: 0.7243 - weighted_sparse_categorical_accuracy: 0.7243 - val_loss: 3.7411 - val_sparse_categorical_accuracy: 0.4221 - val_weighted_sparse_categorical_accuracy: 0.4221
# Epoch 48/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 0.9870 - sparse_categorical_accuracy: 0.7260 - weighted_sparse_categorical_accuracy: 0.7260 - val_loss: 3.7463 - val_sparse_categorical_accuracy: 0.4224 - val_weighted_sparse_categorical_accuracy: 0.4224
# Epoch 49/50
# 1233/1233 [==============================] - 23s 19ms/step - loss: 0.9781 - sparse_categorical_accuracy: 0.7279 - weighted_sparse_categorical_accuracy: 0.7279 - val_loss: 3.8014 - val_sparse_categorical_accuracy: 0.4220 - val_weighted_sparse_categorical_accuracy: 0.4220
# Epoch 50/50
# 1233/1233 [==============================] - 23s 18ms/step - loss: 0.9723 - sparse_categorical_accuracy: 0.7291 - weighted_sparse_categorical_accuracy: 0.7291 - val_loss: 3.7882 - val_sparse_categorical_accuracy: 0.4222 - val_weighted_sparse_categorical_accuracy: 0.4222
# CPU times: user 23min 49s, sys: 2min 33s, total: 26min 23s
# Wall time: 19min 14s

# %% [markdown]
# ## Inference

# %%
model.load_weights(checkpoint_filepath)

# %%
def decode_sequence(features, words):
    output_tokens = model.predict([features, features, words])

    # Sample a token
    decoded_sentence = np.squeeze(np.argmax(output_tokens, axis=2))
    sentence = list(map(lambda x : NoteVocab.index2note[x], decoded_sentence))
    return sentence

# %%
instance_id = 46789
print(decode_sequence(np.expand_dims(features[instance_id], axis=0), np.expand_dims(words[instance_id], axis=0)))
print(list(map(lambda x : NoteVocab.index2note[x], labels[instance_id])))
# Out:
# ['SOS', 'C5_S', 'D5', 'BREAK', 'D5_S', 'D5', 'D5', 'D5', 'BREAK', 'E5_S', 'E5', 'E5', 'E5', 'E5', 'E5', 'BREAK', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS']
# ['SOS', 'D#4_S', 'D#4', 'BREAK', 'G4_S', 'G4', 'G4', 'G4', 'BREAK', 'F4_S', 'F4', 'F4', 'F4', 'F4', 'F4', 'BREAK', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS', 'EOS']

# %%
eval_hist = model.evaluate(
    x=[features_test, features_test, words_test],
    y=labels_test,
)
# Out:
# 444/444 [==============================] - 2s 5ms/step - loss: nan - sparse_categorical_accuracy: 0.3958 - weighted_sparse_categorical_accuracy: 0.3958

# %% [markdown]
# ## Evaluation

# %%
plt.plot(history['sparse_categorical_accuracy'], label='Training Accuracy')
plt.plot(history['val_sparse_categorical_accuracy'], label='Validation Set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

x = np.linspace(0,epochs - 1)
y = np.full(x.shape, eval_hist[1])
plt.plot(x, y, label='Test set Accuracy')

plt.title("Accuracy")
plt.legend()
plt.show()
